# %%
Project Title: Online Car Rental Platform

Project Objective: 
Build an online car rental platform using Object-Oriented Programming in Python.

Problem Statement:
A car rental company has requested you to build an online car rental platform where customers should be able to view the available cars that can be rented on an hourly, daily, or weekly basis. The company can display the available inventory and confirm requests by checking the available stock. Customers will receive an auto-generated bill when they return the car.

For simplicity, let’s assume that:
1.	Customers can rent cars from any one of the following options—hourly, daily, or weekly rental.
2.	Customers are free to choose any number of cars they want, provided the number of available cars is more than the number of requested cars.


You must use the following tools:
Jupyter Notebook: To create the module and main project files

Instructions to Perform:

1.	Create a module (.py file) for car rental and import the built-in module DateTime to handle the rental time and bill.
2.	Create a class for renting the cars and define a constructor in it.
3.	Define a method for displaying the available cars. Also, define methods for renting cars on an hourly, daily and weekly basis, respectively.
4.	Inside these methods, make sure that the number of requested cars is positive and lesser than the total available cars.
5.	Store the time of renting a car in a variable, which can later be used in the bill while returning the car. 
6.	Define a method to return the cars using rental time, rental mode (hourly, daily, or weekly), and the number of cars rented.
7.	Inside the return method; update the inventory stock, calculate the rental period, and generate the final bill.
8.	Create a class for customers and define a constructor in it.
9.	Define methods for requesting the cars and returning them. 
10.	Next, create the main project (.ipynb) file and import the car rental module in it.
11.	Define the main method and create objects for both car rental and customer classes.
12.	Inside the main method, take the customer’s input as a choice for displaying car availability, rental modes, or returning the cars.
13.	Use the relevant method for the customer’s input and print relevant messages.
14.	Run the main method to start your project.

# %%
class car():
    def __init__(self,stock):
        self.stock=stock
    def displaycar(self):
        print("Total cars in stock",self.stock)
    def rentforcaronHourlyBasis(self,q):
        if q<=0:
            print("Enter the positive value or greater than zero")
        elif q>self.stock:
            print("Enter the value less then stock") 
        else:
            print("You will be charged 100 for each hour per car.")
            print("Total price=",q*100)
            print("Total cars remain in stock",self.stock-q)
            print("you has successfully rented car")
            print("We hope that you enjoy our service.")
            print("Thank you!!")
    def returnforcaronHourlyBasis(self,q):
        if q<=0:
            print("Enter the positive value or greater than zero")
        elif q>self.stock:
            print("Enter the value less then stock") 
        else:
            print("Rental mode = hourly")
            print("You will be charged 100 for each hour per car.")
            print("Total price=",q*100)
            print(x)
            print("you has successfully returned car")
            print("We hope that you enjoy our service.")
            print("Thank you!!")
        
        
    def rentforcarondailyBasis(self,q):
        if q<=0:
            print("Enter the positive value or greater than zero")
        elif q>self.stock:
            print("Enter the value less then stock") 
        else:
            print("You will be charged 2,400 for each daily per car.")
            print("Total price=",q*2400)
            print("Total cars remain in stock",self.stock-q)
            print("you has successfully rented car")
            print("We hope that you enjoy our service.")
            print("Thank you!!")
    def returnforcarondailyBasis(self,q):
        if q<=0:
            print("Enter the positive value or greater than zero")
        elif q>self.stock:
            print("Enter the value less then stock") 
        else:
            print("Rental mode = Daily")
            print("You will be charged 2,400 for each daily per car.")
            print("Total price=",q*2400)
            print(x)
            print("you has successfully returned car")
            print("We hope that you enjoy our service.")
            print("Thank you!!")       
            
            
    def rentforcaronweeklyBasis(self,q):
        if q<=0:
            print("Enter the positive value or greater than zero")
        elif q>self.stock:
            print("Enter the value less then stock") 
        else:
            print("You will be charged 16,800 for each weekly per car.")
            print("Total price=",q*16800)
            print("Total cars remain in stock",self.stock-q)
            print("you has successfully rented car")
            print("We hope that you enjoy our service.")
            print("Thank you!!")
    def returnforcaronweeklyBasis(self,q):
        if q<=0:
            print("Enter the positive value or greater than zero")
        elif q>self.stock:
            print("Enter the value less then stock") 
        else:
            print("Rental mode = weekly")
            print("You will be charged 16,800 for each weekly per car.")
            print("Total price=",q*16800)
            print(x)
            print("you has successfully returned car")
            print("We hope that you enjoy our service.")
            print("Thank you!!")
import datetime
x = datetime.datetime.now()  
        
print("********Welcome to the Car Rental Shop**********")
print("Hii Dear customer, i am your vertual assistant and I am very happy to welcome you in our Car Rental Shop.") 
while True:   
        obj=car(100)
        userchoice =int(input('''
        What can i help you with today?
        1.Total numbers of available cars
        2.Request a car on hourly basis Rs.100/-
        3.Request a car on daily basis Rs.2,400/-
        4.Request a car on weekly basis Rs.16,800/-
        5.Return car(Hourlybasis) - bill generate
        6.Return car(dailybasis) - bill generate
        7.Return car(weeklybasis) - bill generate
        8.Exit
        '''))
        
        if userchoice==1:
             obj.displaycar()
        elif userchoice==2:
            n=int(input("Enter the quantity:"))
            obj.rentforcaronHourlyBasis(n)
        elif userchoice==3:
            n=int(input("Enter the quantity:"))  
            obj.rentforcarondailyBasis(n)
        elif userchoice==4:
            n=int(input("Enter the quantity:"))
            obj.rentforcaronweeklyBasis(n)
        elif userchoice==5:
            n=int(input("Enter the quantity:"))
            obj.returnforcaronHourlyBasis(n)
        elif userchoice==6:
            n=int(input("Enter the quantity:"))
            obj.returnforcarondailyBasis(n)
        elif userchoice==7:
            n=int(input("Enter the quantity:"))
            obj.returnforcaronweeklyBasis(n)     
                
        elif userchoice==8:
            break
        else:
            print("Invalid input. Please enter number between 1-6 ")        
            print("Thank you for using the car rental system.")
# Out:
# ********Welcome to the Car Rental Shop**********
# Hii Dear customer, i am your vertual assistant and I am very happy to welcome you in our Car Rental Shop.
#         What can i help you with today?
#         1.Total numbers of available cars
#         2.Request a car on hourly basis Rs.100/-
#         3.Request a car on daily basis Rs.2,400/-
#         4.Request a car on weekly basis Rs.16,800/-
#         5.Return car(Hourlybasis) - bill generate
#         6.Return car(dailybasis) - bill generate
#         7.Return car(weeklybasis) - bill generate
#         8.Exit
#          5
# Enter the quantity: 2
# Rental mode = hourly
# You will be charged 100 for each hour per car.
# Total price= 200
# 2024-01-21 15:49:08.676002
# you has successfully returned car
# We hope that you enjoy our service.
# Thank you!!
#         What can i help you with today?
#         1.Total numbers of available cars
#         2.Request a car on hourly basis Rs.100/-
# ...
